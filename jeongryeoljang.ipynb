# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv('2020년+1월_2월.csv')

# 불필요 열삭제 
del df['가맹점ID'], df['가맹점명'], df['가맹점주(가입자)'], df['고객명'], df['고객 생년월일'], df['고객 성별'], df['승인번호'], df['승인일자']

df
# Out:
#           승인시간   거래금액      카테고리
# 0       184905  95000  미용/뷰티/위생
# 1       124115   2500        분식
# 2       134644   7000        분식
# 3       121408   8000        분식
# 4       115700  17000        분식
# ...        ...    ...       ...
# 172215  160128  32000     일반음식점
# 172216  142158  10000     일반음식점
# 172217  142246  10000     일반음식점
# 172218  184133   5000     일반음식점
# 172219  150324  11500     일반음식점
#
# [172220 rows x 3 columns]

# %%
# 승인시간 추출 : 승인시간 2 
df['승인시간'] = df['승인시간'].apply(str)
df['승인시간'] = df['승인시간'].str.zfill(6)
df['승인시간2'] = pd.to_numeric(df['승인시간'].str[0:2])

# 카테고리 분류 변경 
df['카테고리'].replace('가구판매점','슈퍼/마트', inplace=True)
df['카테고리'].replace('가발','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('가방.핸드백','의류/잡화/안경', inplace=True)
df['카테고리'].replace('가전/통신','가전/통신', inplace=True)
df['카테고리'].replace('가전제품','가전/통신', inplace=True)
df['카테고리'].replace('건강보조식품','스포츠/헬스', inplace=True)
df['카테고리'].replace('골프연습장','스포츠/헬스', inplace=True)
df['카테고리'].replace('교복','의류/잡화/안경', inplace=True)
df['카테고리'].replace('교육 및 교구','학원/교육', inplace=True)
df['카테고리'].replace('구두.신발','의류/잡화/안경', inplace=True)
df['카테고리'].replace('기계.장비(기타)','기타', inplace=True)
df['카테고리'].replace('기술.직업훈련학원','학원/교육', inplace=True)
df['카테고리'].replace('기타','기타', inplace=True)
df['카테고리'].replace('기타 가정.주방용품','의류/잡화/안경', inplace=True)
df['카테고리'].replace('기타 건축자재','의류/잡화/안경', inplace=True)
df['카테고리'].replace('기타 교육.교습.학원','학원/교육', inplace=True)
df['카테고리'].replace('기타 대인서비스','기타', inplace=True)
df['카테고리'].replace('기타 레저,스포츠용품','스포츠/헬스', inplace=True)
df['카테고리'].replace('기타 상품 판매점','슈퍼/마트', inplace=True)
df['카테고리'].replace('기타 서비스','기타', inplace=True)
df['카테고리'].replace('기타 수리.수선전문','전통시장/상점가', inplace=True)
df['카테고리'].replace('기타 숙박업소','숙박/캠핑', inplace=True)
df['카테고리'].replace('기타 식음료품','전통시장/상점가', inplace=True)
df['카테고리'].replace('기타 약품.의료기기','병원/약국', inplace=True)
df['카테고리'].replace('기타 연료판매','자동차/자전거', inplace=True)
df['카테고리'].replace('기타 오락.휴식시설','도서/문화/공연', inplace=True)
df['카테고리'].replace('기타 음식점','일반음식점', inplace=True)
df['카테고리'].replace('기타 의료업','병원/약국', inplace=True)
df['카테고리'].replace('기타 잡화','의류/잡화/안경', inplace=True)
df['카테고리'].replace('기타 장비임대','전통시장/상점가', inplace=True)
df['카테고리'].replace('기타 전문서비스','기타', inplace=True)
df['카테고리'].replace('기타 종합소매점','슈퍼/마트', inplace=True)
df['카테고리'].replace('기타 취미.레저.스포츠','스포츠/헬스', inplace=True)
df['카테고리'].replace('내과','병원/약국', inplace=True)
df['카테고리'].replace('내의류','의류/잡화/안경', inplace=True)
df['카테고리'].replace('노래방','전통시장/상점가', inplace=True)
df['카테고리'].replace('농산물,청과물','전통시장/상점가', inplace=True)
df['카테고리'].replace('농수축협직판장','슈퍼/마트', inplace=True)
df['카테고리'].replace('농협식품전문점','슈퍼/마트', inplace=True)
df['카테고리'].replace('당구장','스포츠/헬스', inplace=True)
df['카테고리'].replace('도서/문화/공연','도서/문화/공연', inplace=True)
df['카테고리'].replace('동물병원','병원/약국', inplace=True)
df['카테고리'].replace('레저','레저', inplace=True)
df['카테고리'].replace('레저용 숙박업소','레저', inplace=True)
df['카테고리'].replace('무술도장','스포츠/헬스', inplace=True)
df['카테고리'].replace('문구,사무용품','의류/잡화/안경', inplace=True)
df['카테고리'].replace('미용/뷰티/위생','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('미용실(두발전문)','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('미용재료','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('민예품,공예품','의류/잡화/안경', inplace=True)
df['카테고리'].replace('병원/약국','병원/약국', inplace=True)
df['카테고리'].replace('보일러,펌프,샷시','부동산/인테리어', inplace=True)
df['카테고리'].replace('부동산 중개','부동산/인테리어', inplace=True)
df['카테고리'].replace('부동산/인테리어','부동산/인테리어', inplace=True)
df['카테고리'].replace('분식','분식', inplace=True)
df['카테고리'].replace('뷔페.출장연회','일반음식점', inplace=True)
df['카테고리'].replace('비료.사료.종자','전통시장/상점가', inplace=True)
df['카테고리'].replace('사우나.목욕탕.찜질방','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('사진관. 현상소','전통시장/상점가', inplace=True)
df['카테고리'].replace('산모/육아','병원/약국', inplace=True)
df['카테고리'].replace('산부인과','병원/약국', inplace=True)
df['카테고리'].replace('산후조리원','병원/약국', inplace=True)
df['카테고리'].replace('서양식전문점','일반음식점', inplace=True)
df['카테고리'].replace('서적','도서/문화/공연', inplace=True)
df['카테고리'].replace('성형외과','병원/약국', inplace=True)
df['카테고리'].replace('세차장','자동차/자전거', inplace=True)
df['카테고리'].replace('세탁업','의류/잡화/안경', inplace=True)
df['카테고리'].replace('소비조합(구내매점)','슈퍼/마트', inplace=True)
df['카테고리'].replace('소아과','병원/약국', inplace=True)
df['카테고리'].replace('수산물,건어물','전통시장/상점가', inplace=True)
df['카테고리'].replace('숙박/캠핑','숙박/캠핑', inplace=True)
df['카테고리'].replace('슈퍼/마트','슈퍼/마트', inplace=True)
df['카테고리'].replace('슈퍼마켓.마트','슈퍼/마트', inplace=True)
df['카테고리'].replace('스포츠/헬스','스포츠/헬스', inplace=True)
df['카테고리'].replace('시계. 귀금속','전통시장/상점가', inplace=True)
df['카테고리'].replace('시장/거리','전통시장/상점가', inplace=True)
df['카테고리'].replace('식음료(기타)','일반음식점', inplace=True)
df['카테고리'].replace('신경정신과','병원/약국', inplace=True)
df['카테고리'].replace('실내장식 (인테리어)','부동산/인테리어', inplace=True)
df['카테고리'].replace('아동.유아복','의류/잡화/안경', inplace=True)
df['카테고리'].replace('아이스크림전문점','일반음식점', inplace=True)
df['카테고리'].replace('악기 판매점','전통시장/상점가', inplace=True)
df['카테고리'].replace('안경.광학제품','의류/잡화/안경', inplace=True)
df['카테고리'].replace('안과','병원/약국', inplace=True)
df['카테고리'].replace('애완동물,용품','전통시장/상점가', inplace=True)
df['카테고리'].replace('약국','병원/약국', inplace=True)
df['카테고리'].replace('여행사','레저', inplace=True)
df['카테고리'].replace('영화.공연장','도서/문화/공연', inplace=True)
df['카테고리'].replace('예식장','전통시장/상점가', inplace=True)
df['카테고리'].replace('예체능 계열 학원','학원/교육', inplace=True)
df['카테고리'].replace('오토바이','자동차/자전거', inplace=True)
df['카테고리'].replace('완구','전통시장/상점가', inplace=True)
df['카테고리'].replace('외과','병원/약국', inplace=True)
df['카테고리'].replace('외국어학원','학원/교육', inplace=True)
df['카테고리'].replace('요양.보육.복지시설','병원/약국', inplace=True)
df['카테고리'].replace('요양병원','병원/약국', inplace=True)
df['카테고리'].replace('의류/잡화/안경','의류/잡화/안경', inplace=True)
df['카테고리'].replace('의류관련(기타)','의류/잡화/안경', inplace=True)
df['카테고리'].replace('의약품판매','병원/약국', inplace=True)
df['카테고리'].replace('이발소','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('이비인후과','병원/약국', inplace=True)
df['카테고리'].replace('인삼 전문점','전통시장/상점가', inplace=True)
df['카테고리'].replace('일반병원','병원/약국', inplace=True)
df['카테고리'].replace('일반음식점','일반음식점', inplace=True)
df['카테고리'].replace('일반의류','의류/잡화/안경', inplace=True)
df['카테고리'].replace('일식전문점','일반음식점', inplace=True)
df['카테고리'].replace('입시학원,보습학원','학원/교육', inplace=True)
df['카테고리'].replace('자동차/자전거','자동차/자전거', inplace=True)
df['카테고리'].replace('자동차운전학원','자동차/자전거', inplace=True)
df['카테고리'].replace('자동차정비','자동차/자전거', inplace=True)
df['카테고리'].replace('자전거','자동차/자전거', inplace=True)
df['카테고리'].replace('전문 스포츠용품점','스포츠/헬스', inplace=True)
df['카테고리'].replace('전통시장/상점가','전통시장/상점가', inplace=True)
df['카테고리'].replace('정수기.비데','전통시장/상점가', inplace=True)
df['카테고리'].replace('정형외과','병원/약국', inplace=True)
df['카테고리'].replace('제과.제빵','일반음식점', inplace=True)
df['카테고리'].replace('조명기구. 전기','전통시장/상점가', inplace=True)
df['카테고리'].replace('종합 스포츠용품점','전통시장/상점가', inplace=True)
df['카테고리'].replace('주차장.폐차장','자동차/자전거', inplace=True)
df['카테고리'].replace('중고품 판매점','전통시장/상점가', inplace=True)
df['카테고리'].replace('중식전문점','일반음식점', inplace=True)
df['카테고리'].replace('차량부품.용품','자동차/자전거', inplace=True)
df['카테고리'].replace('철재,사무용 가구','전통시장/상점가', inplace=True)
df['카테고리'].replace('축산물,정육점','전통시장/상점가', inplace=True)
df['카테고리'].replace('치과','병원/약국', inplace=True)
df['카테고리'].replace('치킨전문점','일반음식점', inplace=True)
df['카테고리'].replace('침구 및 수예품','전통시장/상점가', inplace=True)
df['카테고리'].replace('카페/베이커리','일반음식점', inplace=True)
df['카테고리'].replace('커튼.카펫.수건','전통시장/상점가', inplace=True)
df['카테고리'].replace('커피전문점','일반음식점', inplace=True)
df['카테고리'].replace('컴퓨터 및 소프트웨어','가전/통신', inplace=True)
df['카테고리'].replace('타이어 판매점','자동차/자전거', inplace=True)
df['카테고리'].replace('택배 서비스','전통시장/상점가', inplace=True)
df['카테고리'].replace('테마파크(놀이시설)','도서/문화/공연', inplace=True)
df['카테고리'].replace('통신기기','가전/통신', inplace=True)
df['카테고리'].replace('판촉물.인쇄.복사','전통시장/상점가', inplace=True)
df['카테고리'].replace('패스트푸드점','일반음식점', inplace=True)
df['카테고리'].replace('편의점','슈퍼/마트', inplace=True)
df['카테고리'].replace('피부.체형미 관리','미용/뷰티/위생', inplace=True)
df['카테고리'].replace('피부과','병원/약국', inplace=True)
df['카테고리'].replace('학원/교육','학원/교육', inplace=True)
df['카테고리'].replace('한국인삼공사','전통시장/상점가', inplace=True)
df['카테고리'].replace('한방병원','병원/약국', inplace=True)
df['카테고리'].replace('한약방','병원/약국', inplace=True)
df['카테고리'].replace('한의원','병원/약국', inplace=True)
df['카테고리'].replace('헬스클럽','스포츠/헬스', inplace=True)
df['카테고리'].replace('호텔 (특급외)','숙박/캠핑', inplace=True)
df['카테고리'].replace('화방.표구점','전통시장/상점가', inplace=True)
df['카테고리'].replace('화원.화초','전통시장/상점가', inplace=True)
df['카테고리'].replace('화장품','미용/뷰티/위생', inplace=True)

df
# Out:
#           승인시간   거래금액      카테고리  승인시간2
# 0       184905  95000  미용/뷰티/위생     18
# 1       124115   2500        분식     12
# 2       134644   7000        분식     13
# 3       121408   8000        분식     12
# 4       115700  17000        분식     11
# ...        ...    ...       ...    ...
# 172215  160128  32000     일반음식점     16
# 172216  142158  10000     일반음식점     14
# 172217  142246  10000     일반음식점     14
# 172218  184133   5000     일반음식점     18
# 172219  150324  11500     일반음식점     15
#
# [172220 rows x 4 columns]

# %%
# 시간대별 거래금액 집계 
totalamount = pd.pivot_table(df, index='승인시간2', values='거래금액', aggfunc=np.sum)
print(totalamount)

# 최대 거래시간 
maxtime = totalamount['거래금액'].idxmax()
print('최대 거래시간:'+ str(maxtime) + '시')

# 최소 거래시간 
mintime = totalamount['거래금액'].idxmin()
print('최소 거래시간:'+ str(mintime) + '시')
# Out:
#             거래금액
# 승인시간2
# 0       26880010
# 1       18919270
# 2        4977910
# 3        2560850
# 4         444450
# 5        1034350
# 6        4606890
# 7       22064220
# 8       40029676
# 9      107911490
# 10     205020945
# 11     282021396
# 12     464727421
# 13     433268210
# 14     423315617
# 15     459362584
# 16     454379380
# 17     484678726
# 18     529643507
# 19     510435322
# 20     414263683
# 21     228460266
# 22     119110470
# 23      66084516
# 최대 거래시간:18시
# 최소 거래시간:4시

# %%
# 차트 설정 
plt.rc('font', family='Malgun Gothic')
plt.rcParams["figure.figsize"] = (20, 10)

# 시간대별 거래금액 차트
# plt.bar(totalamount.index, totalamount['거래금액']/100000000)
ax = sns.barplot(x=totalamount.index, y=totalamount['거래금액']/100000000, data=totalamount, palette="coolwarm")
plt.title('시간대별 거래금액', fontsize = 15)
plt.xlabel("시간대", fontsize = 10)
plt.ylabel("거래금액(단위:억원)", fontsize = 10)
plt.xticks(range(24))
for a,b in zip(totalamount.index, round(totalamount['거래금액']/100000000, 3)):      
     # if a == maxtime :        
        plt.text(a, b+0.05, str(b), horizontalalignment='center')           
plt.show()
#plt.savefig('time.png')

# %%
#  시간대별 카테고리 이용 빈도수 집계 
totalcategory = pd.pivot_table(df, index = ['승인시간2', '카테고리'], values = '거래금액', aggfunc=np.sum)
print(totalcategory)

# 거래금액 최대 시간대 카테고리 이용 빈도수 표시 
"""
maxcategory = totalcategory.loc[maxtime]
print('2')
maxsort = maxcategory.sort_values(by='거래금액', ascending=False)
print('3')
print(maxsort)
print('\n')

ax1 = sns.barplot(x=maxsort.index, y=maxsort['거래금액'], data=maxsort, palette="coolwarm")
plt.title('거래금액 최대 시간대 카테고리 이용 빈도수 : ' + str(maxtime) + '시', fontsize = 15)   
plt.xlabel('')
plt.ylabel('빈도수')
plt.show()
plt.savefig('max.png')

# 거래금액 최소 시간대 카테고리 이용 빈도수 표시 
mincategory = totalcategory.loc[mintime]
minsort = mincategory.sort_values(by='거래금액', ascending=False)
print(minsort)
print('\n')

ax2 = sns.barplot(x=minsort.index, y=minsort['거래금액'], data=minsort, palette="coolwarm")
plt.title('거래금액 최소 시간대 카테고리 이용 빈도수 : ' + str(mintime) + '시', fontsize = 15)   
plt.xlabel('')
plt.ylabel('빈도수')
plt.show()
plt.savefig('min.png')
"""

# 시간대별 카테고리 이용 빈도수 차트 
for i  in range(24) : 
    temp = totalcategory.loc[i].sort_values(by='거래금액', ascending=False)
    print(str(i)+'시')
    print(temp)
    print('\n')
    sns.barplot(x=temp.index, y=temp['거래금액'], data=temp, palette='coolwarm')       
    plt.title(str(i) + '시 카테고리별 이용 빈도수')   
    plt.xlabel('')
    plt.ylabel('빈도수')
    #totalcategory.loc[i].plot.bar()
    plt.show()
    filename = str(i) + '.png'
    # plt.savefig(filename)
# Out:
#                     거래금액
# 승인시간2 카테고리
# 0     기타          968500
#       도서/문화/공연    121200
#       레저          201000
#       미용/뷰티/위생     67500
#       병원/약국        47500
# ...                  ...
# 23    스포츠/헬스     1742100
#       일반음식점     23315396
#       자동차/자전거       6500
#       전통시장/상점가   2602080
#       학원/교육     15185000
#
# [316 rows x 1 columns]
# 0시
#               거래금액
# 카테고리
# 일반음식점     11314180
# 학원/교육      7215540
# 슈퍼/마트      2895190
# 부동산/인테리어   1750000
# 전통시장/상점가   1407800
# 기타          968500
# 스포츠/헬스      808700
# 레저          201000
# 도서/문화/공연    121200
# 숙박/캠핑        80000
# 미용/뷰티/위생     67500
# 병원/약국        47500
# 자동차/자전거       2900
# 1시
#              거래금액
# 카테고리
# 일반음식점     7130750
# 기타        6971900
# 부동산/인테리어  1410000
# 전통시장/상점가  1209000
# 슈퍼/마트     1132520
# 학원/교육      450000
# 병원/약국      269500
# 도서/문화/공연   160100
# 숙박/캠핑      110000
# 스포츠/헬스      62000
# 미용/뷰티/위생    10000
# 자동차/자전거      3500
# 2시
#              거래금액
# 카테고리
# 일반음식점     3844350
# 기타         500000
# 슈퍼/마트      409860
# 도서/문화/공연    75700
# 스포츠/헬스      55000
# 전통시장/상점가    50000
# 미용/뷰티/위생    43000
# 3시
#              거래금액
# 카테고리
# 일반음식점     1271600
# 기타         640020
# 슈퍼/마트      292030
# 학원/교육      150000
# 전통시장/상점가   130000
# 스포츠/헬스      45000
# 도서/문화/공연    32200
# 4시
#             거래금액
# 카테고리
# 일반음식점     247900
# 슈퍼/마트     185050
# 스포츠/헬스     10000
# 도서/문화/공연    1500
# 5시
#             거래금액
# 카테고리
# 슈퍼/마트     632950
# 일반음식점     150300
# 전통시장/상점가  135000
# 미용/뷰티/위생   47000
# 도서/문화/공연   28000
# 기타         27100
# 스포츠/헬스     14000
# 6시
#              거래금액
# 카테고리
# 슈퍼/마트     1640480
# 일반음식점      779200
# 전통시장/상점가   643710
# 스포츠/헬스     596000
# 학원/교육      450000
# 미용/뷰티/위생   357500
# 기타         124000
# 의류/잡화/안경    10000
# 도서/문화/공연     6000
# 7시
#              거래금액
# 카테고리
# 학원/교육     5433600
# 전통시장/상점가  4373240
# 기타        3989690
# 슈퍼/마트     3636140
# 부동산/인테리어  2006600
# 일반음식점     1851950
# 미용/뷰티/위생   511000
# 도서/문화/공연    94400
# 스포츠/헬스      60500
# 의류/잡화/안경    40300
# 병원/약국       34000
# 분식          31500
# 자동차/자전거      1300
# 8시
#              거래금액
# 카테고리
# 학원/교육     8255000
# 일반음식점     7830260
# 슈퍼/마트     7494970
# 전통시장/상점가  5889586
# 병원/약국     4704860
# 기타        2134820
# 부동산/인테리어  2027940
# 의류/잡화/안경   690170
# 미용/뷰티/위생   324660
# 스포츠/헬스     283000
# 자동차/자전거    220400
# 도서/문화/공연   129910
# 분식          44100
# 9시
#               거래금액
# 카테고리
# 병원/약국     31537360
# 슈퍼/마트     19319240
# 학원/교육     16090000
# 전통시장/상점가  11490840
# 일반음식점      9784740
# 기타         8301510
# 스포츠/헬스     4495500
# 부동산/인테리어   3737000
# 의류/잡화/안경   1150240
# 자동차/자전거     816670
# 미용/뷰티/위생    793700
# 도서/문화/공연    204540
# 분식          160150
# 숙박/캠핑        30000
# 10시
#               거래금액
# 카테고리
# 병원/약국     55009755
# 슈퍼/마트     34613044
# 전통시장/상점가  23396910
# 학원/교육     21969600
# 기타        21589940
# 일반음식점     18189986
# 부동산/인테리어  11980580
# 미용/뷰티/위생   4452300
# 의류/잡화/안경   4326540
# 자동차/자전거    3945690
# 스포츠/헬스     3185900
# 도서/문화/공연   1296100
# 레저          496000
# 분식          350840
# 숙박/캠핑       143760
# 가전/통신        74000
# 11시
#               거래금액
# 카테고리
# 병원/약국     63691570
# 일반음식점     40243761
# 슈퍼/마트     39287320
# 기타        37080056
# 전통시장/상점가  35669879
# 학원/교육     25991200
# 미용/뷰티/위생  11120770
# 스포츠/헬스     8563050
# 의류/잡화/안경   6561820
# 부동산/인테리어   5927700
# 자동차/자전거    4005280
# 도서/문화/공연   2474550
# 분식         1023540
# 가전/통신       322900
# 레저           58000
# 12시
#                거래금액
# 카테고리
# 일반음식점     203365953
# 병원/약국      52175890
# 슈퍼/마트      49184360
# 기타         44056380
# 전통시장/상점가   42022565
# 학원/교육      27211223
# 미용/뷰티/위생   12177520
# 의류/잡화/안경    8852500
# 부동산/인테리어    8402300
# 스포츠/헬스      8200700
# 자동차/자전거     3818590
# 도서/문화/공연    2203700
# 분식          1690640
# 숙박/캠핑        664100
# 가전/통신        581000
# 레저           120000
# 13시
#                거래금액
# 카테고리
# 일반음식점     149675705
# 기타         56938070
# 전통시장/상점가   53875495
# 슈퍼/마트      47628020
# 학원/교육      39359000
# 병원/약국      20201350
# 미용/뷰티/위생   15434920
# 스포츠/헬스     14424020
# 부동산/인테리어   14168000
# 의류/잡화/안경   11335820
# 자동차/자전거     4701710
# 도서/문화/공연    3446900
# 분식          1201800
# 숙박/캠핑        780900
# 레저            96500
# 14시
#                거래금액
# 카테고리
# 일반음식점     102262445
# 학원/교육      61754100
# 기타         58396060
# 전통시장/상점가   52369757
# 슈퍼/마트      48863540
# 병원/약국      35610410
# 부동산/인테리어   16793000
# 미용/뷰티/위생   13962850
# 스포츠/헬스     12840600
# 의류/잡화/안경    9561515
# 자동차/자전거     4626700
# 도서/문화/공연    3972940
# 분식           994500
# 가전/통신        865000
# 레저           378000
# 숙박/캠핑         64200
# 15시
#               거래금액
# 카테고리
# 학원/교육     75982700
# 기타        68203008
# 전통시장/상점가  64152568
# 슈퍼/마트     62210359
# 일반음식점     60253089
# 병원/약국     48290610
# 부동산/인테리어  20209000
# 미용/뷰티/위생  16269430
# 스포츠/헬스    15341440
# 의류/잡화/안경  11713630
# 자동차/자전거    7956911
# 도서/문화/공연   7266020
# 분식          879320
# 가전/통신       254000
# 레저          225499
# 숙박/캠핑       155000
# 16시
#               거래금액
# 카테고리
# 학원/교육     77632020
# 슈퍼/마트     76287668
# 기타        69397750
# 전통시장/상점가  62198876
# 일반음식점     52349332
# 병원/약국     49990774
# 부동산/인테리어  20643040
# 미용/뷰티/위생  15676420
# 의류/잡화/안경  10295070
# 스포츠/헬스     9985520
# 도서/문화/공연   4074050
# 자동차/자전거    3847440
# 분식         1082520
# 가전/통신       682400
# 숙박/캠핑       152500
# 레저           84000
# 17시
#               거래금액
# 카테고리
# 학원/교육     99737850
# 슈퍼/마트     82697790
# 전통시장/상점가  71715272
# 일반음식점     70419423
# 기타        60263975
# 병원/약국     32619489
# 부동산/인테리어  24897500
# 미용/뷰티/위생  13772387
# 의류/잡화/안경  11137460
# 스포츠/헬스    10064620
# 자동차/자전거    3489790
# 도서/문화/공연   2284710
# 분식         1011760
# 가전/통신       220000
# 숙박/캠핑       200700
# 레저          146000
# 18시
#                거래금액
# 카테고리
# 일반음식점     140587135
# 슈퍼/마트      85832129
# 학원/교육      82103300
# 전통시장/상점가   73813648
# 기타         55781060
# 병원/약국      25637865
# 부동산/인테리어   24148700
# 스포츠/헬스     15892760
# 미용/뷰티/위생   11096330
# 의류/잡화/안경    7769560
# 도서/문화/공연    4008000
# 분식          1047520
# 레저           873300
# 자동차/자전거      719900
# 가전/통신        224000
# 숙박/캠핑        108300
# 19시
#                거래금액
# 카테고리
# 일반음식점     204954878
# 학원/교육      79746600
# 슈퍼/마트      61042314
# 기타         48568580
# 전통시장/상점가   43350090
# 부동산/인테리어   20286900
# 스포츠/헬스     13618000
# 미용/뷰티/위생   13046450
# 병원/약국      12223780
# 의류/잡화/안경    8729510
# 도서/문화/공연    1306100
# 분식          1262420
# 숙박/캠핑       1040500
# 자동차/자전거     1014200
# 가전/통신        179000
# 레저            66000
# 20시
#                거래금액
# 카테고리
# 일반음식점     193123346
# 학원/교육      62870840
# 슈퍼/마트      53790357
# 기타         34577370
# 전통시장/상점가   25767582
# 부동산/인테리어   11620000
# 스포츠/헬스     10066460
# 미용/뷰티/위생    8750418
# 병원/약국       4584330
# 의류/잡화/안경    4539120
# 도서/문화/공연    2127060
# 자동차/자전거     1025200
# 레저           789000
# 분식           453600
# 숙박/캠핑        179000
# 21시
#               거래금액
# 카테고리
# 일반음식점     94911570
# 학원/교육     42210100
# 슈퍼/마트     40950826
# 전통시장/상점가  16414780
# 기타        12251290
# 부동산/인테리어   9540000
# 스포츠/헬스     6646620
# 미용/뷰티/위생   2241580
# 도서/문화/공연    950800
# 의류/잡화/안경    930950
# 병원/약국       600800
# 레저          384000
# 분식          286800
# 자동차/자전거     108650
# 숙박/캠핑        25000
# 가전/통신         6500
# 22시
#               거래금액
# 카테고리
# 일반음식점     43929680
# 학원/교육     27187900
# 슈퍼/마트     24224190
# 기타         8590730
# 스포츠/헬스     4184100
# 전통시장/상점가   4099440
# 부동산/인테리어   3839000
# 미용/뷰티/위생   1246000
# 병원/약국       901630
# 도서/문화/공연    356100
# 의류/잡화/안경    137700
# 숙박/캠핑       120000
# 분식          105200
# 레저           97000
# 자동차/자전거      91800
# 23시
#               거래금액
# 카테고리
# 일반음식점     23315396
# 학원/교육     15185000
# 기타         9318360
# 슈퍼/마트      7042080
# 부동산/인테리어   6000000
# 전통시장/상점가   2602080
# 스포츠/헬스     1742100
# 미용/뷰티/위생    627000
# 도서/문화/공연    162900
# 숙박/캠핑        55000
# 병원/약국        18000
# 분식           10100
# 자동차/자전거       6500
